# %%
import os
import json
import pandas as pd
import itertools
from typing import List, Dict, Any
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
from langchain_qdrant import QdrantVectorStore
from dotenv import load_dotenv

# %%
# Diretórios principais
BASE_DIR = BASE_DIR = os.getcwd()
DIR_PAI = os.path.dirname(BASE_DIR)  # Diretório pai
DIR_SRC = os.path.join(DIR_PAI,'src')  # Diretório src
DIR_VECTORSTORE = os.path.join(DIR_SRC,'vector_store') 
DIR_DATA = os.path.join(DIR_PAI, "data")  # Diretório de dados
DIR_DATA_RAW = os.path.join(DIR_DATA, "raw")  # Diretório para dados brutos
DIR_LOGS =  os.path.join(DIR_DATA, "logs") # Diretório de logs
DIR_DATA_REFINEMENT = os.path.join(DIR_DATA, "outputs_vision_and_extractor")  # Diretório de refinamento

# %%
class CollectionCreator:
    def __init__(self, config_file: str):
        self.config = self.load_config(config_file)
        load_dotenv()
        self.qdrant_url = os.getenv("QDRANT_URL")
        self.qdrant_api_key = os.getenv("QDRANT_API_KEY")

        if not self.qdrant_url or not self.qdrant_api_key:
            raise ValueError("Variáveis QDRANT_URL ou QDRANT_API_KEY não encontradas!")

        # Carrega os metadados do CSV
        self.file_to_metadata = self.load_metadata_from_csv()

    def load_config(self, config_file: str) -> Dict[str, Any]:
        """Carrega o arquivo de configuração JSON."""
        with open(config_file, 'r', encoding='utf-8') as f:
            return json.load(f)

    def load_metadata_from_csv(self) -> Dict[str, Dict[str, Any]]:
        """Carrega o CSV e cria um mapeamento arquivo_id -> metadados."""
        csv_path = os.path.join(DIR_DATA, "subcategoria_name.csv")
        df = pd.read_csv(csv_path)
        metadata_dict = df.set_index("arquivo_id").to_dict(orient="index")
        print("Metadados carregados do CSV:", metadata_dict)
        return metadata_dict

    def load_json_documents(self, file_id: str) -> List[Document]:
        """Carrega arquivos JSON, adiciona metadados do CSV e páginas."""
        dir_path = os.path.join(self.config['pdf_dir'], file_id)

        if not os.path.isdir(dir_path):
            print(f"Diretório {dir_path} não existe. Pulando.")
            return []

        documents = []
        for fname in os.listdir(dir_path):
            if fname.endswith("_resultado.json"):
                fpath = os.path.join(dir_path, fname)
                with open(fpath, 'r', encoding='utf-8') as f:
                    data = json.load(f)

                # Extração de informações
                text = data.get("unified_analysis", "")
                page_number = data.get("page", None)
                metadata = {
                    "source": fname,
                    "pag": page_number
                }

                # Adiciona metadados do CSV
                try:
                    arquivo_id = int(fname.split("_")[1])  # Extrai arquivo_id do nome do arquivo
                    metadata["arquivo_id"] = arquivo_id
                    if arquivo_id in self.file_to_metadata:
                        csv_metadata = self.file_to_metadata[arquivo_id]
                        metadata.update(csv_metadata)
                    else:
                        print(f"Nenhum metadado encontrado para arquivo_id {arquivo_id}")
                except (IndexError, ValueError):
                    print(f"Erro ao extrair arquivo_id de {fname}")

                print("Metadados finais para o documento:", metadata)
                documents.append(Document(page_content=text, metadata=metadata))

        return documents

    def clean_metadata(self, metadata: dict) -> dict:
        """Garante que o metadata seja serializável e limpo."""
        return {k: v for k, v in metadata.items() if isinstance(v, (str, int, float, bool, list, dict))}

    def create_collection(self, collection_config: Dict[str, Any]):
        embeddings_model = collection_config['embeddings_model']
        local_embeddings = HuggingFaceEmbeddings(model_name=embeddings_model, model_kwargs={'trust_remote_code': True})

        documents = collection_config['documents']
        chunk_size = collection_config['chunk_size']
        chunk_overlap = collection_config['chunk_overlap']

        # Se chunk_size == "Page", não faz chunking adicional
        if chunk_size == "Page":
            splits = documents
        else:
            # chunk_size deve ser inteiro
            if isinstance(chunk_size, str):
                raise ValueError("chunk_size deve ser 'Page' ou um inteiro.")
            if chunk_overlap is None:
                chunk_overlap = 0
            text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
            splits = text_splitter.split_documents(documents)

        for doc in splits:
            doc.metadata = self.clean_metadata(doc.metadata)

        QdrantVectorStore.from_documents(
            documents=splits,
            embedding=local_embeddings,
            url=self.qdrant_url,
            api_key=self.qdrant_api_key,
            collection_name=collection_config['collection_name'],
            force_recreate=True
        )

        print(f"Collection {collection_config['collection_name']} criada com sucesso.")

    def generate_collection_configs(self, documents_dict: Dict[str, List[Document]]) -> List[Dict[str, Any]]:
        embeddings_models = self.config['embeddings_models']
        chunk_sizes = self.config['chunk_sizes']
        chunk_overlaps = self.config['chunk_overlaps']

        all_docs = []
        for docs in documents_dict.values():
            all_docs.extend(docs)

        combos = itertools.product(embeddings_models, chunk_sizes, chunk_overlaps)
        configs = []
        for emb_model, c_size, c_overlap in combos:
            chunk_display = c_size if c_size != "Page" else "by-page"
            collection_name = f"{self.config['collection_name']}_chunk{chunk_display}_overlap{c_overlap}_{emb_model.split('/')[-1]}"
            extraction_config = {
                "collection_name": collection_name,
                "chunk_size": c_size,
                "chunk_overlap": c_overlap,
                "embeddings_model": emb_model,
                "documents": all_docs,
            }
            configs.append(extraction_config)

        return configs

    def create_collections(self):
        documents_dict = {}
        for arquivo_id in self.config['arquivo_ids_to_process']:
            if not arquivo_id.startswith("fluidos_"):
                continue
            docs = self.load_json_documents(arquivo_id)
            if docs:
                documents_dict[arquivo_id] = docs

        self.collection_configs = self.generate_collection_configs(documents_dict)

        for collection_config in self.collection_configs:
            self.create_collection(collection_config)

# %%
if __name__ == "__main__":
    config_file = os.path.join(DIR_VECTORSTORE, "config.json")
    processor = CollectionCreator(config_file)
    processor.create_collections()
# Out:
# Metadados carregados do CSV: {11484: {'subcategoria_nome': 'fluidos'}, 11640: {'subcategoria_nome': 'fluidos'}, 13271: {'subcategoria_nome': 'fluidos'}, 13417: {'subcategoria_nome': 'fluidos'}, 13472: {'subcategoria_nome': 'fluidos'}, 13572: {'subcategoria_nome': 'fluidos'}, 13852: {'subcategoria_nome': 'fluidos'}, 4802: {'subcategoria_nome': 'fluidos'}}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag10_resultado.json', 'pag': 10, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag11_resultado.json', 'pag': 11, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag12_resultado.json', 'pag': 12, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag13_resultado.json', 'pag': 13, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag14_resultado.json', 'pag': 14, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag15_resultado.json', 'pag': 15, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag16_resultado.json', 'pag': 16, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag17_resultado.json', 'pag': 17, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag18_resultado.json', 'pag': 18, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag19_resultado.json', 'pag': 19, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag1_resultado.json', 'pag': 1, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag20_resultado.json', 'pag': 20, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag21_resultado.json', 'pag': 21, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag22_resultado.json', 'pag': 22, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag23_resultado.json', 'pag': 23, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag2_resultado.json', 'pag': 2, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag3_resultado.json', 'pag': 3, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag4_resultado.json', 'pag': 4, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag5_resultado.json', 'pag': 5, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag6_resultado.json', 'pag': 6, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag7_resultado.json', 'pag': 7, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag8_resultado.json', 'pag': 8, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13472_pag9_resultado.json', 'pag': 9, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag10_resultado.json', 'pag': 10, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag11_resultado.json', 'pag': 11, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag12_resultado.json', 'pag': 12, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag13_resultado.json', 'pag': 13, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag14_resultado.json', 'pag': 14, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag15_resultado.json', 'pag': 15, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag16_resultado.json', 'pag': 16, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag1_resultado.json', 'pag': 1, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag2_resultado.json', 'pag': 2, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag3_resultado.json', 'pag': 3, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag4_resultado.json', 'pag': 4, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag5_resultado.json', 'pag': 5, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag6_resultado.json', 'pag': 6, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag7_resultado.json', 'pag': 7, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag8_resultado.json', 'pag': 8, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11484_pag9_resultado.json', 'pag': 9, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag10_resultado.json', 'pag': 10, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag11_resultado.json', 'pag': 11, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag12_resultado.json', 'pag': 12, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag13_resultado.json', 'pag': 13, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag14_resultado.json', 'pag': 14, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag15_resultado.json', 'pag': 15, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag16_resultado.json', 'pag': 16, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag17_resultado.json', 'pag': 17, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag18_resultado.json', 'pag': 18, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag19_resultado.json', 'pag': 19, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag1_resultado.json', 'pag': 1, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag2_resultado.json', 'pag': 2, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag3_resultado.json', 'pag': 3, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag4_resultado.json', 'pag': 4, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag5_resultado.json', 'pag': 5, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag6_resultado.json', 'pag': 6, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag7_resultado.json', 'pag': 7, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag8_resultado.json', 'pag': 8, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13852_pag9_resultado.json', 'pag': 9, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag10_resultado.json', 'pag': 10, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag11_resultado.json', 'pag': 11, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag12_resultado.json', 'pag': 12, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag13_resultado.json', 'pag': 13, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag14_resultado.json', 'pag': 14, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag15_resultado.json', 'pag': 15, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag16_resultado.json', 'pag': 16, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag1_resultado.json', 'pag': 1, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag2_resultado.json', 'pag': 2, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag3_resultado.json', 'pag': 3, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag4_resultado.json', 'pag': 4, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag5_resultado.json', 'pag': 5, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag6_resultado.json', 'pag': 6, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag7_resultado.json', 'pag': 7, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag8_resultado.json', 'pag': 8, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_11640_pag9_resultado.json', 'pag': 9, 'arquivo_id': 11640, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag10_resultado.json', 'pag': 10, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag11_resultado.json', 'pag': 11, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag12_resultado.json', 'pag': 12, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag13_resultado.json', 'pag': 13, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag14_resultado.json', 'pag': 14, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag15_resultado.json', 'pag': 15, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag16_resultado.json', 'pag': 16, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag17_resultado.json', 'pag': 17, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag18_resultado.json', 'pag': 18, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag19_resultado.json', 'pag': 19, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag1_resultado.json', 'pag': 1, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag2_resultado.json', 'pag': 2, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag3_resultado.json', 'pag': 3, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag4_resultado.json', 'pag': 4, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag5_resultado.json', 'pag': 5, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag6_resultado.json', 'pag': 6, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag7_resultado.json', 'pag': 7, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag8_resultado.json', 'pag': 8, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13271_pag9_resultado.json', 'pag': 9, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag10_resultado.json', 'pag': 10, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag11_resultado.json', 'pag': 11, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag12_resultado.json', 'pag': 12, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag13_resultado.json', 'pag': 13, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag14_resultado.json', 'pag': 14, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag15_resultado.json', 'pag': 15, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag16_resultado.json', 'pag': 16, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag17_resultado.json', 'pag': 17, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag18_resultado.json', 'pag': 18, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag19_resultado.json', 'pag': 19, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag1_resultado.json', 'pag': 1, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag20_resultado.json', 'pag': 20, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag21_resultado.json', 'pag': 21, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag22_resultado.json', 'pag': 22, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag23_resultado.json', 'pag': 23, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag2_resultado.json', 'pag': 2, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag3_resultado.json', 'pag': 3, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag4_resultado.json', 'pag': 4, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag5_resultado.json', 'pag': 5, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag6_resultado.json', 'pag': 6, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag7_resultado.json', 'pag': 7, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag8_resultado.json', 'pag': 8, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13417_pag9_resultado.json', 'pag': 9, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag10_resultado.json', 'pag': 10, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag11_resultado.json', 'pag': 11, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag12_resultado.json', 'pag': 12, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag13_resultado.json', 'pag': 13, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag14_resultado.json', 'pag': 14, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag15_resultado.json', 'pag': 15, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag16_resultado.json', 'pag': 16, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag17_resultado.json', 'pag': 17, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag18_resultado.json', 'pag': 18, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag19_resultado.json', 'pag': 19, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag1_resultado.json', 'pag': 1, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag2_resultado.json', 'pag': 2, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag3_resultado.json', 'pag': 3, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag4_resultado.json', 'pag': 4, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag5_resultado.json', 'pag': 5, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag6_resultado.json', 'pag': 6, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag7_resultado.json', 'pag': 7, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag8_resultado.json', 'pag': 8, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_13572_pag9_resultado.json', 'pag': 9, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag10_resultado.json', 'pag': 10, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag11_resultado.json', 'pag': 11, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag12_resultado.json', 'pag': 12, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag13_resultado.json', 'pag': 13, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag14_resultado.json', 'pag': 14, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag15_resultado.json', 'pag': 15, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag16_resultado.json', 'pag': 16, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag17_resultado.json', 'pag': 17, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag18_resultado.json', 'pag': 18, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag19_resultado.json', 'pag': 19, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag1_resultado.json', 'pag': 1, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag20_resultado.json', 'pag': 20, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag21_resultado.json', 'pag': 21, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag2_resultado.json', 'pag': 2, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag3_resultado.json', 'pag': 3, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag4_resultado.json', 'pag': 4, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag5_resultado.json', 'pag': 5, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag6_resultado.json', 'pag': 6, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag7_resultado.json', 'pag': 7, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag8_resultado.json', 'pag': 8, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Metadados finais para o documento: {'source': 'fluidos_4802_pag9_resultado.json', 'pag': 9, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}
# Collection fluidos_chunkby-page_overlap100_multilingual-e5-large criada com sucesso.
# Collection fluidos_chunkby-page_overlap0_multilingual-e5-large criada com sucesso.

# %% [markdown]
# ### Criação de índices

# %%
from qdrant_client import QdrantClient
from qdrant_client.http import models

# Carregando variáveis de ambiente
QDRANT_URL = os.getenv("QDRANT_URL")
QDRANT_API_KEY = os.getenv("QDRANT_API_KEY")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
COLLECTION_NAME = "fluidos_chunkby-page_overlap0_multilingual-e5-large"          # Substitua pelo nome da sua coleção
FIELD_NAME = "metadata.arquivo_id"                                                 # Campo a ser indexado

# Conexão com o Qdrant com autenticação
client = QdrantClient(
    url=QDRANT_URL,
    api_key=QDRANT_API_KEY  # Adicione a chave de API aqui
)

# %%
# Função para criar o índice no campo especificado
def create_index_for_field(collection_name, field_name):
    try:
        client.create_payload_index(
            collection_name=collection_name,
            field_name=field_name,
            field_schema=models.PayloadSchemaType.KEYWORD,  # Índice do tipo "keyword"
        )
        print(f"Índice criado com sucesso para o campo '{field_name}' na coleção '{collection_name}'.")
    except Exception as e:
        print(f"Erro ao criar índice: {e}")

# Verificação da configuração da coleção
def verify_index(collection_name):
    try:
        collection_info = client.get_collection(collection_name)
        print("Configuração atual da coleção:")
        print(collection_info.model_dump())
    except Exception as e:
        print(f"Erro ao verificar configuração da coleção: {e}")

# Executa a criação do índice e verifica a configuração
if __name__ == "__main__":
    create_index_for_field(COLLECTION_NAME, FIELD_NAME)
    verify_index(COLLECTION_NAME)
# Out:
# Índice criado com sucesso para o campo 'metadata.arquivo_id' na coleção 'fluidos_chunkby-page_overlap0_multilingual-e5-large'.
# Configuração atual da coleção:
# {'status': <CollectionStatus.GREEN: 'green'>, 'optimizer_status': <OptimizersStatusOneOf.OK: 'ok'>, 'vectors_count': None, 'indexed_vectors_count': 0, 'points_count': 156, 'segments_count': 2, 'config': {'params': {'vectors': {'': {'size': 1024, 'distance': <Distance.COSINE: 'Cosine'>, 'hnsw_config': None, 'quantization_config': None, 'on_disk': None, 'datatype': None, 'multivector_config': None}}, 'shard_number': 1, 'sharding_method': None, 'replication_factor': 1, 'write_consistency_factor': 1, 'read_fan_out_factor': None, 'on_disk_payload': True, 'sparse_vectors': {}}, 'hnsw_config': {'m': 16, 'ef_construct': 100, 'full_scan_threshold': 10000, 'max_indexing_threads': 0, 'on_disk': False, 'payload_m': None}, 'optimizer_config': {'deleted_threshold': 0.2, 'vacuum_min_vector_number': 1000, 'default_segment_number': 0, 'max_segment_size': None, 'memmap_threshold': None, 'indexing_threshold': 20000, 'flush_interval_sec': 5, 'max_optimization_threads': None}, 'wal_config': {'wal_capacity_mb': 32, 'wal_segments_ahead': 0}, 'quantization_config': None}, 'payload_schema': {'metadata.arquivo_id': {'data_type': <PayloadSchemaType.KEYWORD: 'keyword'>, 'params': None, 'points': 0}}}

# %%
# Filtrar pontos com arquivo_id igual a 13472
result = client.search(
    collection_name="fluidos_chunkby-page_overlap0_multilingual-e5-large",
    query_vector=[0] * 1024,  # Vetor de consulta (exemplo: vetor nulo)
    limit=10,  # Limite de resultados
    query_filter=models.Filter(  # Atualizado para usar "query_filter"
        must=[
            models.FieldCondition(
                key="arquivo_id",
                match=models.MatchValue(value=13472)  # Valor a ser filtrado
            )
        ]
    )
)

# Exibir os resultados da consulta
for point in result:
    print(f"ID: {point.id}, Metadata: {point.payload}")

# %%
result
# Out:
# []

# %%
collection_info = client.get_collection("fluidos_chunkby-page_overlap0_multilingual-e5-large")
print(collection_info.model_dump())
# Out:
# {'status': <CollectionStatus.GREEN: 'green'>, 'optimizer_status': <OptimizersStatusOneOf.OK: 'ok'>, 'vectors_count': None, 'indexed_vectors_count': 0, 'points_count': 156, 'segments_count': 2, 'config': {'params': {'vectors': {'size': 1024, 'distance': <Distance.COSINE: 'Cosine'>, 'hnsw_config': None, 'quantization_config': None, 'on_disk': None, 'datatype': None, 'multivector_config': None}, 'shard_number': 1, 'sharding_method': None, 'replication_factor': 1, 'write_consistency_factor': 1, 'read_fan_out_factor': None, 'on_disk_payload': True, 'sparse_vectors': None}, 'hnsw_config': {'m': 16, 'ef_construct': 100, 'full_scan_threshold': 10000, 'max_indexing_threads': 0, 'on_disk': False, 'payload_m': None}, 'optimizer_config': {'deleted_threshold': 0.2, 'vacuum_min_vector_number': 1000, 'default_segment_number': 0, 'max_segment_size': None, 'memmap_threshold': None, 'indexing_threshold': 20000, 'flush_interval_sec': 5, 'max_optimization_threads': None}, 'wal_config': {'wal_capacity_mb': 32, 'wal_segments_ahead': 0}, 'quantization_config': None}, 'payload_schema': {'arquivo_id': {'data_type': <PayloadSchemaType.KEYWORD: 'keyword'>, 'params': None, 'points': 0}}}

# %%
points = client.scroll(collection_name="fluidos_chunkby-page_overlap0_multilingual-e5-large", limit=10, )
for point in points[0]:
    print(point.payload)
# Out:
# {'page_content': '# MANUAL TÉCNICO - TRANSMISSÃO AUTOMÁTICA (AC60E)\n\n## FLUIDOS, ADITIVOS E FILTROS - CAPACIDADES E ESPECIFICAÇÕES\n\n### Procedimentos\n\n---\n\n### 1. Procedimento de Drenagem\n\n1. **Medida do Fluido Drenado**\n   - Utilize um objeto graduado com capacidade maior que **9,5 Litros** para medir a quantidade de fluido drenado.\n\n2. **Remoção do Bujão de Drenagem**\n   - Remova o bujão de drenagem e aguarde até que o óleo pare totalmente de escorrer.\n\n3. **Reinstalação do Bujão de Drenagem**\n   - Após a remoção do óleo da transmissão, reinstale o bujão de drenagem com uma nova junta, aplicando um torque de **20 N.m**.\n\n4. **Abastecimento**\n   - Para reabastecer a transmissão com um novo óleo, efetue o procedimento de abastecimento.\n\n---\n\n### 2. Procedimento de Abastecimento\n\n1. **Remoção dos Bujões**\n   - Remova o bujão de abastecimento e o bujão de verificação.\n\n2. **Adição do Fluido**\n   - Adicione através do orifício de abastecimento a quantidade de fluido drenada ou até que o óleo comece a escorrer pelo orifício de verificação. Aguarde até que o fluxo comece a pingar gota a gota.\n\n3. **Instalação do Bujão de Verificação**\n   - Instale o bujão de verificação, aplicando um torque de **20 N.m**.\n\n4. **Adição de Fluido**\n   - Adicione **1,5 Litros** de fluido na transmissão.\n\n5. **Verificação**\n   - Efetue o procedimento de verificação.\n\n---\n\n### 3. Pontos de Drenagem e Abastecimento\n\n- **Abastecimento**\n- **Drenagem**\n- **Verificação**\n\n---\n\n### Observações Técnicas\n\n- O procedimento deve ser seguido cuidadosamente para garantir a correta manutenção da transmissão automática.\n- Utilize as ferramentas adequadas e siga as especificações de torque recomendadas.', 'metadata': {'source': 'fluidos_13572_pag16_resultado.json', 'pag': 16, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}}
# {'page_content': '# Especificações Técnicas de Freio\n\n## FREIO TRASEIRO\n\n### 1. DISCO DE FREIO (SÓLIDO)\n- **Diâmetro:** 300,00 mm\n- **Espessura:** 12,00 mm\n- **Espessura mínima de uso:** 10,00 mm\n- **Espessura mínima de uso (com suporte):** 8,00 mm\n\n### 2. PASTILHA DE FREIO\n- **Espessura mínima de uso:** 8,00 mm\n\n### 3. DISCO DE FREIO (VENTILADO)\n- **Diâmetro:** 330,00 mm\n- **Espessura:** 22,00 mm\n- **Espessura mínima de uso:** 20,00 mm\n- **Espessura mínima de uso (com suporte):** 8,00 mm\n\n---\n\nEsta estrutura unificada apresenta todas as informações técnicas disponíveis sobre os componentes de freio traseiro, organizadas de forma clara e hierárquica.', 'metadata': {'source': 'fluidos_13852_pag5_resultado.json', 'pag': 5, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}}
# {'page_content': '# Manual Doutor-IE: Transmissão Automática (V5A5A - 5 Marchas)\n\n## 1. Fluido da Transmissão Automática\n\n### 1.1 Capacidade\n- **Valor:** Aproximadamente 9,7 Litros\n\n### 1.2 Especificações\n- **Especificação do Fluido:** ATF SP III\n- **Tipo de Óleo:** Sintético\n\n## 2. Pontos de Drenagem e Abastecimento\n\n### 2.1 Componentes\n1. **Tubo de Abastecimento/Verificação**\n2. **Tubo de Retorno do Resfriador da Transmissão**\n3. **Bujão de Drenagem da Transmissão**\n\n## 3. Elementos Visuais\n- Diagrama ilustrativo disponível, mostrando a localização dos tubos de abastecimento e drenagem da transmissão, bem como os componentes associados.\n\n---\n\nEsta estrutura unificada apresenta todas as informações técnicas relevantes sobre a transmissão automática V5A5A de forma clara e organizada, eliminando redundâncias e preenchendo lacunas.', 'metadata': {'source': 'fluidos_13417_pag15_resultado.json', 'pag': 15, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}}
# {'page_content': '# Documento Unificado: Fluidos, Aditivos e Filtros - Capacidades e Especificações\n\n## Seção: FREIO\n\n### FLUIDO DE FREIO\n\n- **Capacidade:** \n  - Manter o nível entre as marcações de MIN e MAX indicadas no reservatório.\n\n- **Especificação:** \n  - DOT 4', 'metadata': {'source': 'fluidos_13572_pag3_resultado.json', 'pag': 3, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}}
# {'page_content': '# Documento Unificado: Diferencial Dianteiro - Fluido\n\n## 1. Óleo do Diferencial Dianteiro\n\n### 1.1 Capacidade na Troca de Óleo\n- **Modelo 195FIA:** 1,1 Litro\n- **Modelo 195FIAFE:** 0,8 Litro\n\n### 1.2 Especificações\n- **API:** GL-5\n- **Tipo de Óleo:** Sintético\n- **Viscosidade:** SAE 75W-85\n\n### 1.3 Torque dos Bujões\n- **Bujão de Abastecimento:**\n  - **Modelo 195FIA:** 35 N.m\n  - **Modelo 195FIAFE:** 35 N.m\n\n- **Bujão de Drenagem:**\n  - **Modelo 195FIA:** 35 N.m\n  - **Modelo 195FIAFE:** 35 N.m\n\n## 2. Pontos de Drenagem e Abastecimento\n- **Bujão de Abastecimento**\n- **Bujão de Drenagem**\n\n---\n\nEste documento contém todas as informações técnicas relevantes sobre o fluido do diferencial dianteiro, incluindo capacidades, especificações e procedimentos de manutenção para os modelos mencionados.', 'metadata': {'source': 'fluidos_13271_pag16_resultado.json', 'pag': 16, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}}
# {'page_content': '# Transmissão Manual (V5MB1 - 5 Marchas)\n\n## Procedimentos\n\n### 1. Procedimento de Drenagem\n1. Prepare um recipiente para recolher o óleo a ser removido. **Nota:** Este óleo não deve ser reutilizado.\n2. Remova o bujão de drenagem e aguarde até que o óleo pare totalmente de escorrer.\n3. Após a remoção do óleo, reinstale o bujão de drenagem aplicando um torque de **37 N·m**.\n\n### 2. Procedimento de Abastecimento\n1. Retire o bujão de abastecimento da transmissão.\n2. Abasteça a transmissão com óleo **SAE 75W85**, **API GL-4** ou superior, até que o nível esteja correto, logo abaixo do orifício de abastecimento.\n3. Reinstale o bujão de abastecimento com uma nova junta, aplicando um torque de **37 N·m**.\n\n### 3. Procedimento de Verificação do Nível de Óleo\n1. Mantenha o veículo estacionado em uma superfície plana e nivelada.\n2. Retire o bujão de abastecimento e confira o nível do óleo:\n   - **Se o nível estiver acima do orifício de abastecimento:** Espere o óleo escorrer até que esteja no nível correto.\n   - **Se o nível estiver abaixo do orifício de abastecimento:** Preencha com óleo **SAE 75W85**, **API GL-4** ou superior, até que o nível correto seja atingido.\n   - **Se o nível estiver correto:** Siga para o próximo passo.\n3. Após o nível do óleo estar correto, reinstale o bujão de abastecimento.\n\n## Atenção\n- Tome cuidado para não permitir a entrada de poeira ou partículas de qualquer forma pelo orifício de abastecimento. \n- Ao final do procedimento, as peças removidas devem sempre ser recolocadas ou substituídas por novas.\n\n## Ilustrações\n- **Figura 1:** Nível Correto de Óleo\n  - Orifício de Abastecimento\n  - Óleo da Transmissão\n- **Figura 2:** Vista da Transmissão\n  - Bujão de Drenagem\n  - Bujão de Abastecimento\n\n## Especificações Técnicas\n- **Torque de Reinstalação dos Bujões:** 37 N·m\n- **Óleo Recomendado:** SAE 75W85, API GL-4 ou superior.', 'metadata': {'source': 'fluidos_13472_pag10_resultado.json', 'pag': 10, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}}
# {'page_content': '# Especificações Técnicas de Freios\n\n## FREIO DIANTEIRO\n### DISCO DE FREIO (VENTILADO)\n- **Diâmetro:** 328,00 mm\n- **Espessura:** 28,00 mm\n- **Espessura Mínima:** 26,40 mm\n- **Empenamento Máximo:** 0,20 mm\n\n### PASTILHA DE FREIO\n- **Espessura Mínima:** 3,70 mm\n\n---\n\n## FREIO TRASEIRO\n### DISCO DE FREIO (VENTILADO)\n- **Diâmetro:** 330,00 mm\n- **Espessura:** 20,00 mm\n- **Espessura Mínima:** 18,40 mm\n- **Empenamento Máximo:** 0,20 mm\n\n### PASTILHA DE FREIO\n- **Espessura Mínima:** 3,70 mm\n\n---\n\n## Notas Adicionais\n- As especificações incluem medidas críticas para o desempenho e segurança do sistema de freio, como diâmetro e espessura do disco e pastilhas de freio.\n- A manutenção dessas medidas é essencial para garantir a eficiência do sistema de frenagem.', 'metadata': {'source': 'fluidos_11484_pag4_resultado.json', 'pag': 4, 'arquivo_id': 11484, 'subcategoria_nome': 'fluidos'}}
# {'page_content': '# Documento Unificado: Especificações Técnicas do Sistema de Ar-Condicionado\n\n## 1. FILTRO DE CABINE\n- **Especificação:**\n  - Toyota: 87139B8010.\n  \n- **Descrição da Localização:**\n  1. Abra o porta-luvas.\n  2. Dentro do porta-luvas, há dois prendedores nas laterais:\n     - Vire o prendedor da esquerda no sentido anti-horário.\n     - Vire o prendedor da direita no sentido horário.\n  3. Retire os prendedores.\n  4. Remova a tampa do filtro.\n  5. Acesso ao filtro de cabine será liberado.\n\n## 2. COMPRESSOR\n- **Marca:** Denso.\n- **Modelo:** 10SRE11C.\n\n## 3. ÓLEO DO COMPRESSOR\n- **Especificação:** ND-Oil 8 (equivalente ao ISO PAG 46).\n\n## 4. GÁS REFRIGERANTE\n- **Capacidade:** 470 a 530 gramas.\n- **Especificação:** R134a.\n\n## 5. LOCALIZAÇÃO\n- **Painel:**\n  - [Localização do painel](image link)\n  \n- **Localização - Detalhada:**\n  - [Localização detalhada do filtro](image link)\n\n---\n\nEste documento reúne todas as informações técnicas necessárias sobre o sistema de ar-condicionado, incluindo especificações dos componentes, fluidos e instruções de acesso ao filtro de cabine.', 'metadata': {'source': 'fluidos_13572_pag1_resultado.json', 'pag': 1, 'arquivo_id': 13572, 'subcategoria_nome': 'fluidos'}}
# {'page_content': '# Documento Unificado: MANUAL DOUTOR-IE - FLUIDOS, ADITIVOS E FILTROS\n\n## 1. EMBREAGEM\n\n### 1.1 FLUIDO\n\n#### 1.1.1 ÓLEO DA EMBREAGEM\n- **CAPACIDADE:**\n  - O nível do óleo da embreagem deve estar sempre entre as marcas "MIN" e "MAX" presentes no reservatório de óleo da embreagem.\n  \n- **ESPECIFICAÇÃO:**\n  - Tipo: DOT 4\n\n---\n\nEste documento reúne as informações técnicas sobre o óleo da embreagem, conforme descrito nas fontes fornecidas.', 'metadata': {'source': 'fluidos_13417_pag3_resultado.json', 'pag': 3, 'arquivo_id': 13417, 'subcategoria_nome': 'fluidos'}}
# {'page_content': '# Documento Unificado: Diferenecial Traseiro - Capacidades e Especificações\n\n---\n\n## Atenção\n- Evitar a entrada de poeira ou partículas no orifício de abastecimento.\n- Após o procedimento, as peças removidas devem ser recolocadas ou substituídas por novas.\n\n---\n\n## Figuras\n- **FIGURA 1**: Nível Correto de Óleo\n  - Descrição: Orifício de abastecimento.\n  \n- **FIGURA 2**: Vista Superior do Diferencial Traseiro\n  - Descrição: Bujão de drenagem e bujão de abastecimento.\n\n---\n\n## Procedimentos para Verificação do Nível de Óleo\n\n1. **Verificação do Nível**:\n   - Com o veículo em uma superfície plana e nivelada, retire o bujão de abastecimento e confira o nível do óleo.\n   - **Se o nível de óleo estiver acima do orifício de abastecimento**:\n     - Remova cuidadosamente o óleo em excesso até que o nível esteja correto, logo abaixo do orifício de abastecimento.\n     - Siga para o passo 02.\n     \n2. **Ajuste do Nível**:\n   - **Se o nível de óleo estiver abaixo do orifício de abastecimento**:\n     - Adicione óleo sintético SAE 75W85 até que o nível correto seja atingido, logo abaixo do orifício de abastecimento.\n   - **Se o nível estiver correto**:\n     - Instale o bujão de abastecimento aplicando um torque referente ao modelo do diferencial traseiro.\n\n---\n\n## Especificações Técnicas\n- **Tipo de Óleo**: Óleo sintético\n- **Viscosidade do Óleo**: SAE 75W85\n\n--- \n\nEste documento contém todas as informações técnicas necessárias sobre o diferencial traseiro, organizadas de forma clara e hierárquica.', 'metadata': {'source': 'fluidos_13271_pag19_resultado.json', 'pag': 19, 'arquivo_id': 13271, 'subcategoria_nome': 'fluidos'}}

# %%
result = client.scroll(
    collection_name="fluidos_chunkby-page_overlap0_multilingual-e5-large",
    scroll_filter=models.Filter(  # Substituir "filter" por "scroll_filter"
        must=[
            models.FieldCondition(
                key="metadata.arquivo_id",
                match=models.MatchValue(value=13472)
            )
        ]
    ),
    limit=10
)
print(result)
# Out:
# ([Record(id='03cff0d9-06eb-4862-876b-4bf3504df162', payload={'page_content': '# MANUAL DOUTOR-IE: FLUIDOS, ADITIVOS E FILTROS - CAPACIDADES E ESPECIFICAÇÕES\n\n## Seção: EMBREAGEM\n\n### 1. FLUIDO\n\n#### 1.1 ÓLEO DA EMBREAGEM\n- **Capacidade:**\n  - O nível de óleo da embreagem deve estar sempre entre as marcas "MIN" e "MAX" presentes no reservatório de óleo da embreagem.\n  \n- **Especificação:**\n  - **Tipo:** DOT 4', 'metadata': {'source': 'fluidos_13472_pag3_resultado.json', 'pag': 3, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}}, vector=None, shard_key=None, order_value=None), Record(id='08baf8ff-683e-46b3-8532-65432bd58cbc', payload={'page_content': '# Manual Doutor-IE: Transmissão Automática (V5A5A - 5 Marchas)\n\n## Fluido\n\n### Óleo da Transmissão Automática\n- **Capacidade:** Aproximadamente 9,7 Litros\n- **Especificação:** ATF SP III\n- **Tipo de Óleo:** Sintético\n\n## Pontos de Drenagem e Abastecimento\n- **Tubo de Abastecimento/Verificação**\n- **Tubo de Retorno do Resfriador da Transmissão**\n- **Bujão de Drenagem da Transmissão**\n\n### Elementos Visuais\n1. **Diagrama da Transmissão:** Ilustração com identificação dos pontos de dreno e abastecimento.\n\n---\n\nEste documento unificado apresenta todas as informações técnicas relevantes sobre a transmissão automática V5A5A, organizadas de forma clara e hierárquica.', 'metadata': {'source': 'fluidos_13472_pag15_resultado.json', 'pag': 15, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}}, vector=None, shard_key=None, order_value=None), Record(id='0aef9ea7-9728-4613-9147-ad7441fa2617', payload={'page_content': '# MANUAL DOUTOR-IE: FLUIDOS, ADITIVOS E FILTROS - CAPACIDADES E ESPECIFICAÇÕES\n\n## MOTOR - FLUIDOS\n\n---\n\n### LÍQUIDO DE ARREFECIMENTO\n- **Capacidade:** 8,5 Litros.\n- **Especificação:**\n  - Pronto para uso: MZ320125 (Mitsubishi Super Long Life Premium Coolant).\n  - Concentrado: Aditivo à base de etilenoglicol.\n- **Proporção de Aditivo Concentrado:**\n  - 50% (4,25 Litros de aditivo + 4,25 Litros de água desmineralizada).\n\n---\n\n### ÓLEO DO MOTOR\n- **Capacidade:**\n  - Troca total (cárter + radiador de óleo + filtro de óleo): 9,3 Litros.\n  - Troca com filtro de óleo: 8,0 Litros.\n  - Troca sem filtro de óleo: 7,0 Litros.\n- **Especificação:**\n  - API: CH-4 ou superior.\n  - ACEA: A3/B4 ou A5/B5.\n- **Tipo de Óleo:** Semissintético.\n- **Viscosidade:**\n  - Veículos até 2013: SAE 15W40.\n  - Veículos 2014 em diante: SAE 10W30.\n- **Torque do Bujão de Drenagem:** 40 N·m (4,08 kgf·m).\n\n---\n\n### TANQUE DE COMBUSTÍVEL\n- **Capacidade:** 70 Litros.\n- **Especificação:** Diesel S10 ou S50.\n\n--- \n\nEste documento unificado apresenta de forma clara e hierárquica todas as informações técnicas relevantes sobre os fluidos do motor, eliminando redundâncias e preenchendo lacunas.', 'metadata': {'source': 'fluidos_13472_pag8_resultado.json', 'pag': 8, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}}, vector=None, shard_key=None, order_value=None), Record(id='1de303e6-27a8-4745-9c8e-fdce8ecb425e', payload={'page_content': '# Documento Unificado: Transmissão Automática (V5A5A - 5 Marchas)\n\n## 1. Esquema da Transmissão Automática (V5A5A)\n- **Elementos Visuais:**\n  - Tubo de Abastecimento/Verificação\n  - Tubo de Retorno do Resfriador da Transmissão\n  - Bujão de Drenagem da Transmissão\n\n## 2. Atenção\n- **Notas Importantes:**\n  - Cuidado para não permitir a entrada de poeira ou partículas pelo orifício de abastecimento.\n  - As peças removidas devem sempre ser recolocadas ou substituídas por novas.\n\n## 3. Procedimento de Drenagem\n- **Passo 01:** Preparar um recipiente para recolher o óleo a ser removido. O óleo não deve ser reutilizado.\n- **Passo 02:** Desconectar o tubo de retorno do resfriador da transmissão.\n- **Passo 03:** Com o seletor do câmbio posicionado na marcha neutra ‘N’, dar partida no motor e mantê-lo em marcha lenta até que o fluido da transmissão pare de escorrer pelo tubo de retorno.\n- **Passo 04:** Desli ...

# %%
from qdrant_client.http import models

result = client.search(
    collection_name="fluidos_chunkby-page_overlap0_multilingual-e5-large",
    query_vector=[0] * 1024,  # Vetor de consulta nulo (exemplo)
    limit=10,
    query_filter=models.Filter(
        must=[
            models.FieldCondition(
                key="arquivo_id",
                match=models.MatchValue(value=13472)
            )
        ]
    )
)

if result:
    for point in result:
        print(f"ID: {point.id}, Metadata: {point.payload}")
else:
    print("Nenhum ponto encontrado com o arquivo_id especificado.")
# Out:
# Nenhum ponto encontrado com o arquivo_id especificado.

# %%
points = client.scroll(
    collection_name="fluidos_chunkby-page_overlap0_multilingual-e5-large",
    scroll_filter=models.Filter(),  # Sem filtro para retornar todos os pontos
    limit=3
)

for point in points[0]:  # points[0] contém os resultados
    print(f"ID: {point.id}, Metadata: {point.payload}")
# Out:
# ID: 00cd91fe-4eb0-4567-86d8-eff318211cdb, Metadata: {'page_content': '# MANUAL DOUTOR-IE: FLUIDOS, ADITIVOS E FILTROS – CAPACIDADES E ESPECIFICAÇÕES\n\n## DIREÇÃO\n\n### FLUIDO\n\n#### Óleo da Direção Hidráulica\n\n- **Capacidade:**\n  - **Motor Frio:**\n    - Temperatura do óleo: 20°C\n    - Nível de óleo deve estar entre as marcas "MIN" e "MAX" na haste de medição.\n  - **Motor Quente:**\n    - Temperatura do óleo: 80°C\n    - Nível de óleo deve estar entre as marcas "MIN" e "MAX" na haste de medição.\n\n- **Especificação:**\n  - G 004 000\n\n### Observações\n\n- Este modelo de veículo possui dois tipos diferentes de direção assistida: elétrica ou hidráulica.\n- O reservatório de fluido da direção encontra-se próximo à torre do amortecedor dianteiro esquerdo.\n\n### Localização do Reservatório no Veículo\n\n- O reservatório de fluido para direção está localizado próximo à torre do amortecedor dianteiro esquerdo. (Imagem ilustrativa disponível no manual).\n\n---\n\nEste documento unificado contém todas as informações técnicas relevantes sobre o fluido da direção hidráulica, suas capacidades, especificações e localização do reservatório no veículo.', 'metadata': {'source': 'fluidos_13852_pag2_resultado.json', 'pag': 2, 'arquivo_id': 13852, 'subcategoria_nome': 'fluidos'}}
# ID: 02df6326-5358-41a2-8370-f7f9c0ba66c5, Metadata: {'page_content': '# Documento Unificado: Transmissão Automática (V4A5A - 4 Marchas)\n\n## 1. Esquema da Transmissão Automática (V4A5A)\n- **Componentes**:\n  - Tubo de Abastecimento/Verificação\n  - Tubo de Retorno do Resfriador da Transmissão\n  - Bujão de Drenagem da Transmissão\n\n## 2. Procedimentos\n\n### 2.1 Atenção\n- As peças removidas devem ser recolocadas ou substituídas por novas.\n- A verificação do nível de fluido da transmissão deve ser realizada na escala de medição ‘HOT’ (quente) com a transmissão em sua temperatura normal de funcionamento (70°C a 80°C).\n\n### 2.2 Procedimento de Verificação\n1. **Aquecimento do Óleo**:\n   - Dirija o carro durante alguns minutos para que o óleo da transmissão atinja a temperatura de funcionamento (70°C a 80°C).\n   \n2. **Preparação**:\n   - Estacione em local plano e seguro.\n   - Acione o freio de mão.\n   - Pressione firmemente o pedal do freio e transite por todas as posições disponíveis no seletor do câmbio, retornando à posição "P".\n\n3. **Verificação do Nível de Fluido**:\n   - Retire a vareta de nível de fluido da transmissão do tubo de verificação/abastecimento.\n   - Limpe a vareta e insira novamente até que encaixe.\n   - Retire a vareta novamente e verifique se o nível do fluido está entre as marcações de máximo e mínimo da escala ‘HOT’ (quente).\n   - Se o nível estiver fora das marcações, corrija o nível do fluido utilizando fluido novo.\n\n## 3. Escala de Medição da Vareta\n- **COLD** (frio): Marcação para medição em temperatura ambiente.\n- **HOT** (quente): Marcação para medição com a transmissão em temperatura normal de funcionamento.\n\n## 4. Observações\n- É crucial seguir as instruções de segurança e verificação para garantir a funcionalidade adequada da transmissão.\n- O uso de fluidos recomendados e a manutenção correta são essenciais para o funcionamento adequado da transmissão automática.', 'metadata': {'source': 'fluidos_13472_pag13_resultado.json', 'pag': 13, 'arquivo_id': 13472, 'subcategoria_nome': 'fluidos'}}
# ID: 07a90d89-5e60-4091-8a71-ac26963db55a, Metadata: {'page_content': '# Documento Unificado: Transmissão Automática - Fluido\n\n## 1. Óleo da Transmissão Automática\n- **Capacidade na troca de óleo:** 2,50 Litros\n- **Capacidade no enchimento a seco:** 7,10 Litros\n- **Especificação:** DEXRON III ATF\n- **Torque do bujão de drenagem:** 23 N·m\n\n## 2. Pontos de Drenagem, Abastecimento e Verificação\n- **Elementos:**\n  - Tubo de verificação/abastecimento\n  - Drenagem\n\n## 3. Manual\n- **Conteúdo:** Fluidos, aditivos e filtros - Capacidades e especificações\n\n---\n\n### Observações\n- As informações foram organizadas de forma hierárquica, eliminando redundâncias e preenchendo lacunas.', 'metadata': {'source': 'fluidos_4802_pag13_resultado.json', 'pag': 13, 'arquivo_id': 4802, 'subcategoria_nome': 'fluidos'}}

# %%
models.Filter(must=[models.FieldCondition(key="metadata.arquivo_id", match=models.MatchAny(any=[13472, 13472]))])
# Out:
# Filter(should=None, min_should=None, must=[FieldCondition(key='metadata.arquivo_id', match=MatchAny(any=[13472, 13472]), range=None, geo_bounding_box=None, geo_radius=None, geo_polygon=None, values_count=None)], must_not=None)
